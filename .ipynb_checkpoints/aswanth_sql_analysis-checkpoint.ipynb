# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Aswanth@880101",
    database="retail_analysis"
)

print("MySQL connected successfully!")
# Out:
# MySQL connected successfully!

# %%
# Cell 1 - Connect MySQL to Python and import data
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine

# Install sqlalchemy if needed
# pip install sqlalchemy pymysql

# Load CSV files
features = pd.read_csv('data/Features data set.csv')
sales = pd.read_csv('data/sales data-set.csv')
stores = pd.read_csv('data/stores data-set.csv')

# Fix dates
sales['Date'] = pd.to_datetime(sales['Date'], dayfirst=True)
features['Date'] = pd.to_datetime(features['Date'], dayfirst=True)

# Connect to MySQL
engine = create_engine('mysql+pymysql://root:Aswanth%40880101@localhost/retail_analysis')

# Import all 3 tables into MySQL
sales.to_sql('sales', engine, if_exists='replace', index=False)
stores.to_sql('stores', engine, if_exists='replace', index=False)
features.to_sql('features', engine, if_exists='replace', index=False)

print("✓ Connected to MySQL successfully!")
print("✓ 3 tables created in retail_analysis database!")
print("✓ sales table:", len(sales), "rows")
print("✓ stores table:", len(stores), "rows")
print("✓ features table:", len(features), "rows")
# Out:
# ✓ Connected to MySQL successfully!
# ✓ 3 tables created in retail_analysis database!
# ✓ sales table: 421570 rows
# ✓ stores table: 45 rows
# ✓ features table: 8190 rows
